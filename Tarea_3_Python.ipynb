# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
datos_raw = pd.read_csv('//content/drive/MyDrive/Startup/Identificación (Capítulo A).csv', encoding='latin-1')
datos_raw.head()
# Out:
#                                                     DIRECTORIO;"DPTO";"MPIO";"CLASE";"COD_LOCALIDAD";"NOMBRE_LOCALIDAD";"COD_UPZ_GRUPO";"NOMBRE_UPZ_GRUPO";"ESTRATO2021";"NOMBRE_ESTRATO";"FEX_C"
# 3004346;11;11001;1;3;"Santa Fe";814;"SANTA FE: ...                                      2266692027239
# 3004347;11;11001;1;14;"Los Mártires";37;"Santa ...                                      8555889419101
# 3004348;11;11001;1;3;"Santa Fe";814;"SANTA FE: ...                                       286103658331
# 3004349;11;11001;1;1;"Usaquén";803;"USAQUÉN: Co...                                      6502122142802
# 3004350;11;11001;1;1;"Usaquén";803;"USAQUÉN: Co...                                      4684068319009

# %%
datos_raw.describe()
# Out:
#        DIRECTORIO;"DPTO";"MPIO";"CLASE";"COD_LOCALIDAD";"NOMBRE_LOCALIDAD";"COD_UPZ_GRUPO";"NOMBRE_UPZ_GRUPO";"ESTRATO2021";"NOMBRE_ESTRATO";"FEX_C"
# count                                       1.064670e+05
# mean                                        1.234952e+13
# std                                         2.140360e+13
# min                                         3.701770e+05
# 25%                                         1.934377e+12
# 50%                                         5.335203e+12
# 75%                                         8.716812e+12
# max                                         9.997273e+13
